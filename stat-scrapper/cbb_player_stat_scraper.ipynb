# %%
import os
import time
import re
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup, Comment

# Constants
CBB_BASE_URL = "https://www.sports-reference.com/cbb/players"
PLAYER_IDS_CSV = "player_ids.csv"  # Your existing NBA player IDs CSV with PlayerName column
COLLEGE_STATS_CSV = "college_players_stats.csv"
START_YEAR = 2010  # Filter seasons from this year onward (2010-11 season)

def get_driver():
    options = Options()
    options.binary_location = r"C:\Program Files\BraveSoftware\Brave-Browser\Application\brave.exe"
    options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--disable-gpu')
    options.add_argument('window-size=1920,1080')
    options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36')
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)
    return driver

def normalize_name_for_college_id(player_name):
    # Lowercase, replace spaces with hyphens, keep existing hyphens, append -1
    name = player_name.lower()
    name = re.sub(r'\s+', '-', name)
    college_id = f"{name}-1"
    return college_id

from io import StringIO

def extract_table_from_html(soup, table_id):
    # Try to find table directly
    table = soup.find('table', id=table_id)
    if table:
        return pd.read_html(StringIO(str(table)))[0]
    # If not found, try inside HTML comments
    comments = soup.find_all(string=lambda text: isinstance(text, Comment))
    for comment in comments:
        comment_soup = BeautifulSoup(comment, 'html.parser')
        table = comment_soup.find('table', id=table_id)
        if table:
            return pd.read_html(StringIO(str(table)))[0]
    return None

def filter_stats_by_season(df, start_year=START_YEAR):
    if df is None or df.empty:
        return None
    if 'Season' not in df.columns:
        return None
    def season_year(season_str):
        try:
            return int(season_str[:4])
        except:
            return None
    df['SeasonYear'] = df['Season'].apply(season_year)
    filtered_df = df[df['SeasonYear'] >= start_year]
    if filtered_df.empty:
        return None
    filtered_df = filtered_df.drop(columns=['SeasonYear'])
    return filtered_df

def scrape_college_stats(driver, player_name):
    college_id = normalize_name_for_college_id(player_name)
    url = f"{CBB_BASE_URL}/{college_id}.html"
    driver.get(url)
    time.sleep(3)  # polite delay to allow page load

    # Check if page exists
    if "Page Not Found" in driver.page_source or "404" in driver.title:
        print(f"College page not found for {player_name} ({college_id})")
        return None, None

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    per_game_df = extract_table_from_html(soup, 'players_per_game')
    advanced_df = extract_table_from_html(soup, 'players_advanced')

    # Filter by season year
    per_game_df = filter_stats_by_season(per_game_df)
    advanced_df = filter_stats_by_season(advanced_df)

    return per_game_df, advanced_df

def append_college_stats_to_csv(player_name, college_id, per_game_df, advanced_df, output_csv=COLLEGE_STATS_CSV):
    if per_game_df is None and advanced_df is None:
        print(f"Skipping {player_name} ({college_id}) because no college stats from {START_YEAR} onwards.")
        return

    # Check if merge keys exist in both dataframes before merging
    merge_keys = ['Season', 'Team']

    # Verify columns exist
    per_game_has_keys = per_game_df is not None and all(key in per_game_df.columns for key in merge_keys)
    advanced_has_keys = advanced_df is not None and all(key in advanced_df.columns for key in merge_keys)

    if per_game_df is not None:
        per_game_df = per_game_df.copy()
        per_game_df['PlayerName'] = player_name
        per_game_df['CollegeID'] = college_id
        print(f"Per-game columns for {player_name}: {per_game_df.columns.tolist()}")

    if advanced_df is not None:
        advanced_df = advanced_df.copy()
        advanced_df['PlayerName'] = player_name
        advanced_df['CollegeID'] = college_id
        print(f"Advanced columns for {player_name}: {advanced_df.columns.tolist()}")

    if per_game_has_keys and advanced_has_keys:
        merged_df = pd.merge(
            per_game_df,
            advanced_df,
            on=merge_keys,
            suffixes=('_per_game', '_adv'),
            how='outer'
        )
        merged_df['PlayerName'] = player_name
        merged_df['CollegeID'] = college_id
    elif per_game_df is not None and not per_game_has_keys:
        print(f"Skipping {player_name} ({college_id}) because per_game_df missing required columns {merge_keys}.")
        return
    elif advanced_df is not None and not advanced_has_keys:
        print(f"Skipping {player_name} ({college_id}) because advanced_df missing required columns {merge_keys}.")
        return
    elif per_game_df is not None:
        merged_df = per_game_df
    else:
        merged_df = advanced_df

    if not os.path.isfile(output_csv):
        merged_df.to_csv(output_csv, index=False)
    else:
        merged_df.to_csv(output_csv, mode='a', header=False, index=False)
    print(f"Appended college stats for {player_name} ({college_id})")

def main():
    driver = get_driver()
    if not os.path.isfile(PLAYER_IDS_CSV):
        print(f"Player IDs CSV '{PLAYER_IDS_CSV}' not found. Please provide it with a 'PlayerName' column.")
        return

    df_players = pd.read_csv(PLAYER_IDS_CSV)
    total_players = len(df_players)

    start_index = 0  # default to start from first player

    if os.path.isfile(COLLEGE_STATS_CSV):
        try:
            df_existing = pd.read_csv(COLLEGE_STATS_CSV)
            if 'CollegeID' in df_existing.columns and not df_existing.empty:
                last_college_id = df_existing['CollegeID'].iloc[-1]
                print(f"Last scraped CollegeID in CSV: {last_college_id}")

                # Find index of last scraped player in df_players
                # Normalize player names to college IDs for matching
                college_ids_list = df_players['PlayerName'].apply(normalize_name_for_college_id).tolist()
                if last_college_id in college_ids_list:
                    last_index = college_ids_list.index(last_college_id)
                    start_index = last_index + 1
                    print(f"Resuming scraping from player index {start_index} ({df_players.iloc[start_index]['PlayerName'] if start_index < total_players else 'End of list'})")
                else:
                    print("Last scraped CollegeID not found in player list, starting from beginning.")
            else:
                print("Existing CSV is empty or missing 'CollegeID' column, starting from beginning.")
        except Exception as e:
            print(f"Warning: Could not read existing stats CSV: {e}")

    for idx in range(start_index, total_players):
        player_name = df_players.iloc[idx]['PlayerName']
        college_id = normalize_name_for_college_id(player_name)

        print(f"Scraping college stats for {player_name} ({college_id}) [{idx+1}/{total_players}]")
        per_game_df, advanced_df = scrape_college_stats(driver, player_name)
        if per_game_df is None and advanced_df is None:
            print(f"No college stats found for {player_name}, skipping.")
            continue
        append_college_stats_to_csv(player_name, college_id, per_game_df, advanced_df)
        time.sleep(3)  # polite delay between requests

    driver.quit()

if __name__ == "__main__":
    main()
# Out:
# Last scraped CollegeID in CSV: antonio-blakeney-1
# Resuming scraping from player index 395 (Will Blalock)
# Scraping college stats for Will Blalock (will-blalock-1) [396/5313]
# No college stats found for Will Blalock, skipping.
# Scraping college stats for George Blaney (george-blaney-1) [397/5313]
# No college stats found for George Blaney, skipping.
# Scraping college stats for Lance Blanks (lance-blanks-1) [398/5313]
# No college stats found for Lance Blanks, skipping.
# Scraping college stats for Ricky Blanton (ricky-blanton-1) [399/5313]
# No college stats found for Ricky Blanton, skipping.
# Scraping college stats for Andray Blatche (andray-blatche-1) [400/5313]
# College page not found for Andray Blatche (andray-blatche-1)
# No college stats found for Andray Blatche, skipping.
# Scraping college stats for Mookie Blaylock (mookie-blaylock-1) [401/5313]
# No college stats found for Mookie Blaylock, skipping.
# Scraping college stats for Eric Bledsoe (eric-bledsoe-1) [402/5313]
# No college stats found for Eric Bledsoe, skipping.
# Scraping college stats for Keljin Blevins (keljin-blevins-1) [403/5313]
# Per-game columns for Keljin Blevins: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Keljin Blevins: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Keljin Blevins (keljin-blevins-1)
# Scraping college stats for Leon Blevins (leon-blevins-1) [404/5313]
# No college stats found for Leon Blevins, skipping.
# Scraping college stats for John Block (john-block-1) [405/5313]
# No college stats found for John Block, skipping.
# Scraping college stats for Mike Bloom (mike-bloom-1) [406/5313]
# No college stats found for Mike Bloom, skipping.
# Scraping college stats for Jaron Blossomgame (jaron-blossomgame-1) [407/5313]
# Per-game columns for Jaron Blossomgame: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Jaron Blossomgame: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Jaron Blossomgame (jaron-blossomgame-1)
# Scraping college stats for Corie Blount (corie-blount-1) [408/5313]
# No college stats found for Corie Blount, skipping.
# Scraping college stats for Mark Blount (mark-blount-1) [409/5313]
# No college stats found for Mark Blount, skipping.
# Scraping college stats for Vander Blue (vander-blue-1) [410/5313]
# Per-game columns for Vander Blue: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Vander Blue: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Vander Blue (vander-blue-1)
# Scraping college stats for Ray Blume (ray-blume-1) [411/5313]
# No college stats found for Ray Blume, skipping.
# Scraping college stats for Nelson Bobb (nelson-bobb-1) [412/5313]
# No college stats found for Nelson Bobb, skipping.
# Scraping college stats for Tony Bobbitt (tony-bobbitt-1) [413/5313]
# No college stats found for Tony Bobbitt, skipping.
# Scraping college stats for Bucky Bockhorn (bucky-bockhorn-1) [414/5313]
# College page not found for Bucky Bockhorn (bucky-bockhorn-1)
# No college stats found for Bucky Bockhorn, skipping.
# Scraping college stats for Buddy Boeheim (buddy-boeheim-1) [415/5313]
# Per-game columns for Buddy Boeheim: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Buddy Boeheim: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Buddy Boeheim (buddy-boeheim-1)
# Scraping college stats for Tom Boerwinkle (tom-boerwinkle-1) [416/5313]
# No college stats found for Tom Boerwinkle, skipping.
# Scraping college stats for Keith Bogans (keith-bogans-1) [417/5313]
# No college stats found for Keith Bogans, skipping.
# Scraping college stats for Bogdan Bogdanović (bogdan-bogdanović-1) [418/5313]
# College page not found for Bogdan Bogdanović (bogdan-bogdanović-1)
# No college stats found for Bogdan Bogdanović, skipping.
# Scraping college stats for Bojan Bogdanović (bojan-bogdanović-1) [419/5313]
# College page not found for Bojan Bogdanović (bojan-bogdanović-1)
# No college stats found for Bojan Bogdanović, skipping.
# Scraping college stats for Muggsy Bogues (muggsy-bogues-1) [420/5313]
# No college stats found for Muggsy Bogues, skipping.
# Scraping college stats for Andrew Bogut (andrew-bogut-1) [421/5313]
# No college stats found for Andrew Bogut, skipping.
# Scraping college stats for Etdrick Bohannon (etdrick-bohannon-1) [422/5313]
# No college stats found for Etdrick Bohannon, skipping.
# Scraping college stats for Bol Bol (bol-bol-1) [423/5313]
# Per-game columns for Bol Bol: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Bol Bol: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Bol Bol (bol-bol-1)
# Scraping college stats for Manute Bol (manute-bol-1) [424/5313]
# College page not found for Manute Bol (manute-bol-1)
# No college stats found for Manute Bol, skipping.
# Scraping college stats for Jonah Bolden (jonah-bolden-1) [425/5313]
# Per-game columns for Jonah Bolden: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Jonah Bolden: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Jonah Bolden (jonah-bolden-1)
# Scraping college stats for Marques Bolden (marques-bolden-1) [426/5313]
# Per-game columns for Marques Bolden: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Marques Bolden: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Marques Bolden (marques-bolden-1)
# Scraping college stats for Bill Bolger (bill-bolger-1) [427/5313]
# No college stats found for Bill Bolger, skipping.
# Scraping college stats for Leandro Bolmaro (leandro-bolmaro-1) [428/5313]
# College page not found for Leandro Bolmaro (leandro-bolmaro-1)
# No college stats found for Leandro Bolmaro, skipping.
# Scraping college stats for Joel Bolomboy (joel-bolomboy-1) [429/5313]
# Per-game columns for Joel Bolomboy: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Joel Bolomboy: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Joel Bolomboy (joel-bolomboy-1)
# Scraping college stats for Doug Bolstorff (doug-bolstorff-1) [430/5313]
# College page not found for Doug Bolstorff (doug-bolstorff-1)
# No college stats found for Doug Bolstorff, skipping.
# Scraping college stats for George Bon Salle (george-bon-salle-1) [431/5313]
# College page not found for George Bon Salle (george-bon-salle-1)
# No college stats found for George Bon Salle, skipping.
# Scraping college stats for Adem Bona (adem-bona-1) [432/5313]
# Per-game columns for Adem Bona: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Adem Bona: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Adem Bona (adem-bona-1)
# Scraping college stats for Phil Bond (phil-bond-1) [433/5313]
# College page not found for Phil Bond (phil-bond-1)
# No college stats found for Phil Bond, skipping.
# Scraping college stats for Walter Bond (walter-bond-1) [434/5313]
# No college stats found for Walter Bond, skipping.
# Scraping college stats for Jordan Bone (jordan-bone-1) [435/5313]
# Per-game columns for Jordan Bone: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Jordan Bone: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Jordan Bone (jordan-bone-1)
# Scraping college stats for Dexter Boney (dexter-boney-1) [436/5313]
# No college stats found for Dexter Boney, skipping.
# Scraping college stats for Isaac Bonga (isaac-bonga-1) [437/5313]
# College page not found for Isaac Bonga (isaac-bonga-1)
# No college stats found for Isaac Bonga, skipping.
# Scraping college stats for Ron Bonham (ron-bonham-1) [438/5313]
# No college stats found for Ron Bonham, skipping.
# Scraping college stats for Anthony Bonner (anthony-bonner-1) [439/5313]
# No college stats found for Anthony Bonner, skipping.
# Scraping college stats for Matt Bonner (matt-bonner-1) [440/5313]
# No college stats found for Matt Bonner, skipping.
# Scraping college stats for Butch Booker (butch-booker-1) [441/5313]
# College page not found for Butch Booker (butch-booker-1)
# No college stats found for Butch Booker, skipping.
# Scraping college stats for Devin Booker (devin-booker-1) [442/5313]
# Per-game columns for Devin Booker: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Devin Booker: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Devin Booker (devin-booker-1)
# Scraping college stats for Melvin Booker (melvin-booker-1) [443/5313]
# No college stats found for Melvin Booker, skipping.
# Scraping college stats for Trevor Booker (trevor-booker-1) [444/5313]
# No college stats found for Trevor Booker, skipping.
# Scraping college stats for Josh Boone (josh-boone-1) [445/5313]
# No college stats found for Josh Boone, skipping.
# Scraping college stats for Ron Boone (ron-boone-1) [446/5313]
# No college stats found for Ron Boone, skipping.
# Scraping college stats for Calvin Booth (calvin-booth-1) [447/5313]
# No college stats found for Calvin Booth, skipping.
# Scraping college stats for Keith Booth (keith-booth-1) [448/5313]
# No college stats found for Keith Booth, skipping.
# Scraping college stats for Bob Boozer (bob-boozer-1) [449/5313]
# No college stats found for Bob Boozer, skipping.
# Scraping college stats for Carlos Boozer (carlos-boozer-1) [450/5313]
# No college stats found for Carlos Boozer, skipping.
# Scraping college stats for Curtis Borchardt (curtis-borchardt-1) [451/5313]
# No college stats found for Curtis Borchardt, skipping.
# Scraping college stats for Jake Bornheimer (jake-bornheimer-1) [452/5313]
# College page not found for Jake Bornheimer (jake-bornheimer-1)
# No college stats found for Jake Bornheimer, skipping.
# Scraping college stats for Lazaro Borrell (lazaro-borrell-1) [453/5313]
# College page not found for Lazaro Borrell (lazaro-borrell-1)
# No college stats found for Lazaro Borrell, skipping.
# Scraping college stats for Ike Borsavage (ike-borsavage-1) [454/5313]
# College page not found for Ike Borsavage (ike-borsavage-1)
# No college stats found for Ike Borsavage, skipping.
# Scraping college stats for Vince Boryla (vince-boryla-1) [455/5313]
# No college stats found for Vince Boryla, skipping.
# Scraping college stats for Chris Bosh (chris-bosh-1) [456/5313]
# No college stats found for Chris Bosh, skipping.
# Scraping college stats for Jim Bostic (jim-bostic-1) [457/5313]
# No college stats found for Jim Bostic, skipping.
# Scraping college stats for Brandon Boston Jr. (brandon-boston-jr.-1) [458/5313]
# College page not found for Brandon Boston Jr. (brandon-boston-jr.-1)
# No college stats found for Brandon Boston Jr., skipping.
# Scraping college stats for Lawrence Boston (lawrence-boston-1) [459/5313]
# No college stats found for Lawrence Boston, skipping.
# Scraping college stats for Tom Boswell (tom-boswell-1) [460/5313]
# No college stats found for Tom Boswell, skipping.
# Scraping college stats for Chris Boucher (chris-boucher-1) [461/5313]
# Per-game columns for Chris Boucher: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Chris Boucher: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Chris Boucher (chris-boucher-1)
# Scraping college stats for James Bouknight (james-bouknight-1) [462/5313]
# Per-game columns for James Bouknight: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for James Bouknight: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for James Bouknight (james-bouknight-1)
# Scraping college stats for Ruben Boumtje-Boumtje (ruben-boumtje-boumtje-1) [463/5313]
# No college stats found for Ruben Boumtje-Boumtje, skipping.
# Scraping college stats for Jamaree Bouyea (jamaree-bouyea-1) [464/5313]
# Per-game columns for Jamaree Bouyea: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Jamaree Bouyea: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Jamaree Bouyea (jamaree-bouyea-1)
# Scraping college stats for Don Boven (don-boven-1) [465/5313]
# No college stats found for Don Boven, skipping.
# Scraping college stats for Cal Bowdler (cal-bowdler-1) [466/5313]
# No college stats found for Cal Bowdler, skipping.
# Scraping college stats for Brian Bowen (brian-bowen-1) [467/5313]
# College page not found for Brian Bowen (brian-bowen-1)
# No college stats found for Brian Bowen, skipping.
# Scraping college stats for Bruce Bowen (bruce-bowen-1) [468/5313]
# No college stats found for Bruce Bowen, skipping.
# Scraping college stats for Ryan Bowen (ryan-bowen-1) [469/5313]
# No college stats found for Ryan Bowen, skipping.
# Scraping college stats for Tommie Bowens (tommie-bowens-1) [470/5313]
# College page not found for Tommie Bowens (tommie-bowens-1)
# No college stats found for Tommie Bowens, skipping.
# Scraping college stats for Anthony Bowie (anthony-bowie-1) [471/5313]
# No college stats found for Anthony Bowie, skipping.
# Scraping college stats for Sam Bowie (sam-bowie-1) [472/5313]
# No college stats found for Sam Bowie, skipping.
# Scraping college stats for Orb Bowling (orb-bowling-1) [473/5313]
# No college stats found for Orb Bowling, skipping.
# Scraping college stats for Ira Bowman (ira-bowman-1) [474/5313]
# No college stats found for Ira Bowman, skipping.
# Scraping college stats for Ky Bowman (ky-bowman-1) [475/5313]
# Per-game columns for Ky Bowman: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Ky Bowman: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Ky Bowman (ky-bowman-1)
# Scraping college stats for Nate Bowman (nate-bowman-1) [476/5313]
# No college stats found for Nate Bowman, skipping.
# Scraping college stats for Donnie Boyce (donnie-boyce-1) [477/5313]
# No college stats found for Donnie Boyce, skipping.
# Scraping college stats for Dennis Boyd (dennis-boyd-1) [478/5313]
# No college stats found for Dennis Boyd, skipping.
# Scraping college stats for Freddie Boyd (freddie-boyd-1) [479/5313]
# No college stats found for Freddie Boyd, skipping.
# Scraping college stats for Ken Boyd (ken-boyd-1) [480/5313]
# No college stats found for Ken Boyd, skipping.
# Scraping college stats for Earl Boykins (earl-boykins-1) [481/5313]
# No college stats found for Earl Boykins, skipping.
# Scraping college stats for Harry Boykoff (harry-boykoff-1) [482/5313]
# No college stats found for Harry Boykoff, skipping.
# Scraping college stats for Winford Boynes (winford-boynes-1) [483/5313]
# No college stats found for Winford Boynes, skipping.
# Scraping college stats for Cedric Bozeman (cedric-bozeman-1) [484/5313]
# No college stats found for Cedric Bozeman, skipping.
# Scraping college stats for Steve Bracey (steve-bracey-1) [485/5313]
# No college stats found for Steve Bracey, skipping.
# Scraping college stats for Craig Brackins (craig-brackins-1) [486/5313]
# No college stats found for Craig Brackins, skipping.
# Scraping college stats for Gary Bradds (gary-bradds-1) [487/5313]
# No college stats found for Gary Bradds, skipping.
# Scraping college stats for Alex Bradley (alex-bradley-1) [488/5313]
# No college stats found for Alex Bradley, skipping.
# Scraping college stats for Alonzo Bradley (alonzo-bradley-1) [489/5313]
# College page not found for Alonzo Bradley (alonzo-bradley-1)
# No college stats found for Alonzo Bradley, skipping.
# Scraping college stats for Avery Bradley (avery-bradley-1) [490/5313]
# No college stats found for Avery Bradley, skipping.
# Scraping college stats for Bill Bradley (bill-bradley-1) [491/5313]
# No college stats found for Bill Bradley, skipping.
# Scraping college stats for Bill Bradley (bill-bradley-1) [492/5313]
# No college stats found for Bill Bradley, skipping.
# Scraping college stats for Charles Bradley (charles-bradley-1) [493/5313]
# No college stats found for Charles Bradley, skipping.
# Scraping college stats for Dudley Bradley (dudley-bradley-1) [494/5313]
# No college stats found for Dudley Bradley, skipping.
# Scraping college stats for Jim Bradley (jim-bradley-1) [495/5313]
# No college stats found for Jim Bradley, skipping.
# Scraping college stats for Joe Bradley (joe-bradley-1) [496/5313]
# No college stats found for Joe Bradley, skipping.
# Scraping college stats for Michael Bradley (michael-bradley-1) [497/5313]
# No college stats found for Michael Bradley, skipping.
# Scraping college stats for Shawn Bradley (shawn-bradley-1) [498/5313]
# No college stats found for Shawn Bradley, skipping.
# Scraping college stats for Tony Bradley (tony-bradley-1) [499/5313]
# Per-game columns for Tony Bradley: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Tony Bradley: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Tony Bradley (tony-bradley-1)
# Scraping college stats for Mark Bradtke (mark-bradtke-1) [500/5313]
# College page not found for Mark Bradtke (mark-bradtke-1)
# No college stats found for Mark Bradtke, skipping.
# Scraping college stats for Marques Bragg (marques-bragg-1) [501/5313]
# No college stats found for Marques Bragg, skipping.
# Scraping college stats for Torraye Braggs (torraye-braggs-1) [502/5313]
# No college stats found for Torraye Braggs, skipping.
# Scraping college stats for A.J. Bramlett (a.j.-bramlett-1) [503/5313]
# College page not found for A.J. Bramlett (a.j.-bramlett-1)
# No college stats found for A.J. Bramlett, skipping.
# Scraping college stats for Adrian Branch (adrian-branch-1) [504/5313]
# No college stats found for Adrian Branch, skipping.
# Scraping college stats for Elton Brand (elton-brand-1) [505/5313]
# No college stats found for Elton Brand, skipping.
# Scraping college stats for Terrell Brandon (terrell-brandon-1) [506/5313]
# No college stats found for Terrell Brandon, skipping.
# Scraping college stats for Malaki Branham (malaki-branham-1) [507/5313]
# Per-game columns for Malaki Branham: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Malaki Branham: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Malaki Branham (malaki-branham-1)
# Scraping college stats for Bob Brannum (bob-brannum-1) [508/5313]
# No college stats found for Bob Brannum, skipping.
# Scraping college stats for Brad Branson (brad-branson-1) [509/5313]
# No college stats found for Brad Branson, skipping.
# Scraping college stats for Jesse Branson (jesse-branson-1) [510/5313]
# College page not found for Jesse Branson (jesse-branson-1)
# No college stats found for Jesse Branson, skipping.
# Scraping college stats for Jarrell Brantley (jarrell-brantley-1) [511/5313]
# Per-game columns for Jarrell Brantley: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Jarrell Brantley: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Jarrell Brantley (jarrell-brantley-1)
# Scraping college stats for Jim Brasco (jim-brasco-1) [512/5313]
# No college stats found for Jim Brasco, skipping.
# Scraping college stats for Mike Bratz (mike-bratz-1) [513/5313]
# No college stats found for Mike Bratz, skipping.
# Scraping college stats for Carl Braun (carl-braun-1) [514/5313]
# College page not found for Carl Braun (carl-braun-1)
# No college stats found for Carl Braun, skipping.
# Scraping college stats for Christian Braun (christian-braun-1) [515/5313]
# Per-game columns for Christian Braun: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Christian Braun: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Christian Braun (christian-braun-1)
# Scraping college stats for Ignas Brazdeikis (ignas-brazdeikis-1) [516/5313]
# Per-game columns for Ignas Brazdeikis: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Ignas Brazdeikis: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Ignas Brazdeikis (ignas-brazdeikis-1)
# Scraping college stats for Tim Breaux (tim-breaux-1) [517/5313]
# No college stats found for Tim Breaux, skipping.
# Scraping college stats for J.R. Bremer (j.r.-bremer-1) [518/5313]
# College page not found for J.R. Bremer (j.r.-bremer-1)
# No college stats found for J.R. Bremer, skipping.
# Scraping college stats for Pete Brennan (pete-brennan-1) [519/5313]
# No college stats found for Pete Brennan, skipping.
# Scraping college stats for Tom Brennan (tom-brennan-1) [520/5313]
# No college stats found for Tom Brennan, skipping.
# Scraping college stats for Randy Breuer (randy-breuer-1) [521/5313]
# No college stats found for Randy Breuer, skipping.
# Scraping college stats for Corey Brewer (corey-brewer-1) [522/5313]
# No college stats found for Corey Brewer, skipping.
# Scraping college stats for Jamison Brewer (jamison-brewer-1) [523/5313]
# No college stats found for Jamison Brewer, skipping.
# Scraping college stats for Jim Brewer (jim-brewer-1) [524/5313]
# No college stats found for Jim Brewer, skipping.
# Scraping college stats for Ron Brewer (ron-brewer-1) [525/5313]
# No college stats found for Ron Brewer, skipping.
# Scraping college stats for Ronnie Brewer (ronnie-brewer-1) [526/5313]
# No college stats found for Ronnie Brewer, skipping.
# Scraping college stats for Primož Brezec (primož-brezec-1) [527/5313]
# College page not found for Primož Brezec (primož-brezec-1)
# No college stats found for Primož Brezec, skipping.
# Scraping college stats for Frankie Brian (frankie-brian-1) [528/5313]
# No college stats found for Frankie Brian, skipping.
# Scraping college stats for Frank Brickowski (frank-brickowski-1) [529/5313]
# No college stats found for Frank Brickowski, skipping.
# Scraping college stats for Junior Bridgeman (junior-bridgeman-1) [530/5313]
# No college stats found for Junior Bridgeman, skipping.
# Scraping college stats for Bill Bridges (bill-bridges-1) [531/5313]
# No college stats found for Bill Bridges, skipping.
# Scraping college stats for Jalen Bridges (jalen-bridges-1) [532/5313]
# Per-game columns for Jalen Bridges: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Jalen Bridges: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Jalen Bridges (jalen-bridges-1)
# Scraping college stats for Mikal Bridges (mikal-bridges-1) [533/5313]
# Per-game columns for Mikal Bridges: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Mikal Bridges: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Mikal Bridges (mikal-bridges-1)
# Scraping college stats for Miles Bridges (miles-bridges-1) [534/5313]
# Per-game columns for Miles Bridges: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Miles Bridges: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Miles Bridges (miles-bridges-1)
# Scraping college stats for Al Brightman (al-brightman-1) [535/5313]
# College page not found for Al Brightman (al-brightman-1)
# No college stats found for Al Brightman, skipping.
# Scraping college stats for Amida Brimah (amida-brimah-1) [536/5313]
# Per-game columns for Amida Brimah: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Amida Brimah: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Amida Brimah (amida-brimah-1)
# Scraping college stats for Aud Brindley (aud-brindley-1) [537/5313]
# No college stats found for Aud Brindley, skipping.
# Scraping college stats for Isaiah Briscoe (isaiah-briscoe-1) [538/5313]
# Per-game columns for Isaiah Briscoe: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Isaiah Briscoe: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Isaiah Briscoe (isaiah-briscoe-1)
# Scraping college stats for John Brisker (john-brisker-1) [539/5313]
# No college stats found for John Brisker, skipping.
# Scraping college stats for Oshae Brissett (oshae-brissett-1) [540/5313]
# Per-game columns for Oshae Brissett: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Oshae Brissett: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Oshae Brissett (oshae-brissett-1)
# Scraping college stats for Allan Bristow (allan-bristow-1) [541/5313]
# No college stats found for Allan Bristow, skipping.
# Scraping college stats for Tyrone Britt (tyrone-britt-1) [542/5313]
# College page not found for Tyrone Britt (tyrone-britt-1)
# No college stats found for Tyrone Britt, skipping.
# Scraping college stats for Wayman Britt (wayman-britt-1) [543/5313]
# No college stats found for Wayman Britt, skipping.
# Scraping college stats for Mike Brittain (mike-brittain-1) [544/5313]
# No college stats found for Mike Brittain, skipping.
# Scraping college stats for Dave Britton (dave-britton-1) [545/5313]
# No college stats found for Dave Britton, skipping.
# Scraping college stats for Izaiah Brockington (izaiah-brockington-1) [546/5313]
# Per-game columns for Izaiah Brockington: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Izaiah Brockington: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Izaiah Brockington (izaiah-brockington-1)
# Scraping college stats for Jon Brockman (jon-brockman-1) [547/5313]
# No college stats found for Jon Brockman, skipping.
# Scraping college stats for Ryan Broekhoff (ryan-broekhoff-1) [548/5313]
# Per-game columns for Ryan Broekhoff: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Ryan Broekhoff: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Ryan Broekhoff (ryan-broekhoff-1)
# Scraping college stats for Jim Brogan (jim-brogan-1) [549/5313]
# No college stats found for Jim Brogan, skipping.
# Scraping college stats for Malcolm Brogdon (malcolm-brogdon-1) [550/5313]
# Per-game columns for Malcolm Brogdon: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Malcolm Brogdon: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Malcolm Brogdon (malcolm-brogdon-1)
# Scraping college stats for Gary Brokaw (gary-brokaw-1) [551/5313]
# No college stats found for Gary Brokaw, skipping.
# Scraping college stats for Price Brookfield (price-brookfield-1) [552/5313]
# No college stats found for Price Brookfield, skipping.
# Scraping college stats for Clarence Brookins (clarence-brookins-1) [553/5313]
# No college stats found for Clarence Brookins, skipping.
# Scraping college stats for Aaron Brooks (aaron-brooks-1) [554/5313]
# No college stats found for Aaron Brooks, skipping.
# Scraping college stats for Armoni Brooks (armoni-brooks-1) [555/5313]
# Per-game columns for Armoni Brooks: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Armoni Brooks: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Armoni Brooks (armoni-brooks-1)
# Scraping college stats for Dillon Brooks (dillon-brooks-1) [556/5313]
# Per-game columns for Dillon Brooks: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Dillon Brooks: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Dillon Brooks (dillon-brooks-1)
# Scraping college stats for Keion Brooks Jr. (keion-brooks-jr.-1) [557/5313]
# College page not found for Keion Brooks Jr. (keion-brooks-jr.-1)
# No college stats found for Keion Brooks Jr., skipping.
# Scraping college stats for Kevin Brooks (kevin-brooks-1) [558/5313]
# No college stats found for Kevin Brooks, skipping.
# Scraping college stats for MarShon Brooks (marshon-brooks-1) [559/5313]
# Per-game columns for MarShon Brooks: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for MarShon Brooks: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for MarShon Brooks (marshon-brooks-1)
# Scraping college stats for Michael Brooks (michael-brooks-1) [560/5313]
# No college stats found for Michael Brooks, skipping.
# Scraping college stats for Scott Brooks (scott-brooks-1) [561/5313]
# No college stats found for Scott Brooks, skipping.
# Scraping college stats for Andre Brown (andre-brown-1) [562/5313]
# No college stats found for Andre Brown, skipping.
# Scraping college stats for Anthony Brown (anthony-brown-1) [563/5313]
# No college stats found for Anthony Brown, skipping.
# Scraping college stats for Bob Brown (bob-brown-1) [564/5313]
# College page not found for Bob Brown (bob-brown-1)
# No college stats found for Bob Brown, skipping.
# Scraping college stats for Bobby Brown (bobby-brown-1) [565/5313]
# No college stats found for Bobby Brown, skipping.
# Scraping college stats for Bruce Brown (bruce-brown-1) [566/5313]
# No college stats found for Bruce Brown, skipping.
# Scraping college stats for Charlie Brown Jr. (charlie-brown-jr.-1) [567/5313]
# College page not found for Charlie Brown Jr. (charlie-brown-jr.-1)
# No college stats found for Charlie Brown Jr., skipping.
# Scraping college stats for Chaundee Brown Jr. (chaundee-brown-jr.-1) [568/5313]
# College page not found for Chaundee Brown Jr. (chaundee-brown-jr.-1)
# No college stats found for Chaundee Brown Jr., skipping.
# Scraping college stats for Chucky Brown (chucky-brown-1) [569/5313]
# No college stats found for Chucky Brown, skipping.
# Scraping college stats for Damone Brown (damone-brown-1) [570/5313]
# No college stats found for Damone Brown, skipping.
# Scraping college stats for Darrel Brown (darrel-brown-1) [571/5313]
# College page not found for Darrel Brown (darrel-brown-1)
# No college stats found for Darrel Brown, skipping.
# Scraping college stats for Dee Brown (dee-brown-1) [572/5313]
# No college stats found for Dee Brown, skipping.
# Scraping college stats for Dee Brown (dee-brown-1) [573/5313]
# No college stats found for Dee Brown, skipping.
# Scraping college stats for Derrick Brown (derrick-brown-1) [574/5313]
# No college stats found for Derrick Brown, skipping.
# Scraping college stats for Devin Brown (devin-brown-1) [575/5313]
# No college stats found for Devin Brown, skipping.
# Scraping college stats for Ernest Brown (ernest-brown-1) [576/5313]
# No college stats found for Ernest Brown, skipping.
# Scraping college stats for Fred Brown (fred-brown-1) [577/5313]
# No college stats found for Fred Brown, skipping.
# Scraping college stats for George Brown (george-brown-1) [578/5313]
# No college stats found for George Brown, skipping.
# Scraping college stats for Gerald Brown (gerald-brown-1) [579/5313]
# No college stats found for Gerald Brown, skipping.
# Scraping college stats for Greg Brown III (greg-brown-iii-1) [580/5313]
# College page not found for Greg Brown III (greg-brown-iii-1)
# No college stats found for Greg Brown III, skipping.
# Scraping college stats for Harold Brown (harold-brown-1) [581/5313]
# No college stats found for Harold Brown, skipping.
# Scraping college stats for Jabari Brown (jabari-brown-1) [582/5313]
# Per-game columns for Jabari Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Jabari Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Jabari Brown (jabari-brown-1)
# Scraping college stats for Jaylen Brown (jaylen-brown-1) [583/5313]
# Per-game columns for Jaylen Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Jaylen Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Jaylen Brown (jaylen-brown-1)
# Scraping college stats for John Brown (john-brown-1) [584/5313]
# No college stats found for John Brown, skipping.
# Scraping college stats for Kedrick Brown (kedrick-brown-1) [585/5313]
# College page not found for Kedrick Brown (kedrick-brown-1)
# No college stats found for Kedrick Brown, skipping.
# Scraping college stats for Kendall Brown (kendall-brown-1) [586/5313]
# Per-game columns for Kendall Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Kendall Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Kendall Brown (kendall-brown-1)
# Scraping college stats for Kobe Brown (kobe-brown-1) [587/5313]
# Per-game columns for Kobe Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Kobe Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Kobe Brown (kobe-brown-1)
# Scraping college stats for Kwame Brown (kwame-brown-1) [588/5313]
# No college stats found for Kwame Brown, skipping.
# Scraping college stats for Larry Brown (larry-brown-1) [589/5313]
# No college stats found for Larry Brown, skipping.
# Scraping college stats for Leon Brown (leon-brown-1) [590/5313]
# College page not found for Leon Brown (leon-brown-1)
# No college stats found for Leon Brown, skipping.
# Scraping college stats for Lewis Brown (lewis-brown-1) [591/5313]
# No college stats found for Lewis Brown, skipping.
# Scraping college stats for Lorenzo Brown (lorenzo-brown-1) [592/5313]
# Per-game columns for Lorenzo Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Lorenzo Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Lorenzo Brown (lorenzo-brown-1)
# Scraping college stats for Marcus Brown (marcus-brown-1) [593/5313]
# No college stats found for Marcus Brown, skipping.
# Scraping college stats for Markel Brown (markel-brown-1) [594/5313]
# Per-game columns for Markel Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Markel Brown: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Markel Brown (markel-brown-1)
# ...
# Appended college stats for Chris Wright (chris-wright-1)
# Scraping college stats for Chris Wright (chris-wright-1) [5253/5313]
# Per-game columns for Chris Wright: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Chris Wright: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Chris Wright (chris-wright-1)
# Scraping college stats for Delon Wright (delon-wright-1) [5254/5313]
# Per-game columns for Delon Wright: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Delon Wright: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Delon Wright (delon-wright-1)
# Scraping college stats for Dorell Wright (dorell-wright-1) [5255/5313]
# College page not found for Dorell Wright (dorell-wright-1)
# No college stats found for Dorell Wright, skipping.
# Scraping college stats for Howard Wright (howard-wright-1) [5256/5313]
# No college stats found for Howard Wright, skipping.
# Scraping college stats for Howie Wright (howie-wright-1) [5257/5313]
# College page not found for Howie Wright (howie-wright-1)
# No college stats found for Howie Wright, skipping.
# Scraping college stats for Joby Wright (joby-wright-1) [5258/5313]
# No college stats found for Joby Wright, skipping.
# Scraping college stats for Julian Wright (julian-wright-1) [5259/5313]
# No college stats found for Julian Wright, skipping.
# Scraping college stats for Larry Wright (larry-wright-1) [5260/5313]
# Per-game columns for Larry Wright: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Larry Wright: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Larry Wright (larry-wright-1)
# Scraping college stats for Leroy Wright (leroy-wright-1) [5261/5313]
# No college stats found for Leroy Wright, skipping.
# Scraping college stats for Lonnie Wright (lonnie-wright-1) [5262/5313]
# No college stats found for Lonnie Wright, skipping.
# Scraping college stats for Lorenzen Wright (lorenzen-wright-1) [5263/5313]
# No college stats found for Lorenzen Wright, skipping.
# Scraping college stats for Luther Wright (luther-wright-1) [5264/5313]
# No college stats found for Luther Wright, skipping.
# Scraping college stats for McKinley Wright IV (mckinley-wright-iv-1) [5265/5313]
# College page not found for McKinley Wright IV (mckinley-wright-iv-1)
# No college stats found for McKinley Wright IV, skipping.
# Scraping college stats for Moses Wright (moses-wright-1) [5266/5313]
# Per-game columns for Moses Wright: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Moses Wright: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Moses Wright (moses-wright-1)
# Scraping college stats for Sharone Wright (sharone-wright-1) [5267/5313]
# No college stats found for Sharone Wright, skipping.
# Scraping college stats for Justin Wright-Foreman (justin-wright-foreman-1) [5268/5313]
# Per-game columns for Justin Wright-Foreman: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Justin Wright-Foreman: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Justin Wright-Foreman (justin-wright-foreman-1)
# Scraping college stats for Tony Wroten (tony-wroten-1) [5269/5313]
# Per-game columns for Tony Wroten: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Tony Wroten: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Tony Wroten (tony-wroten-1)
# Scraping college stats for Dennis Wuycik (dennis-wuycik-1) [5270/5313]
# No college stats found for Dennis Wuycik, skipping.
# Scraping college stats for A.J. Wynder (a.j.-wynder-1) [5271/5313]
# College page not found for A.J. Wynder (a.j.-wynder-1)
# No college stats found for A.J. Wynder, skipping.
# Scraping college stats for Guerschon Yabusele (guerschon-yabusele-1) [5272/5313]
# College page not found for Guerschon Yabusele (guerschon-yabusele-1)
# No college stats found for Guerschon Yabusele, skipping.
# Scraping college stats for Vincent Yarbrough (vincent-yarbrough-1) [5273/5313]
# No college stats found for Vincent Yarbrough, skipping.
# Scraping college stats for George Yardley (george-yardley-1) [5274/5313]
# No college stats found for George Yardley, skipping.
# Scraping college stats for Barry Yates (barry-yates-1) [5275/5313]
# No college stats found for Barry Yates, skipping.
# Scraping college stats for Wayne Yates (wayne-yates-1) [5276/5313]
# College page not found for Wayne Yates (wayne-yates-1)
# No college stats found for Wayne Yates, skipping.
# Scraping college stats for Charlie Yelverton (charlie-yelverton-1) [5277/5313]
# No college stats found for Charlie Yelverton, skipping.
# Scraping college stats for Rich Yonakor (rich-yonakor-1) [5278/5313]
# No college stats found for Rich Yonakor, skipping.
# Scraping college stats for Gabe York (gabe-york-1) [5279/5313]
# Per-game columns for Gabe York: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Gabe York: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Gabe York (gabe-york-1)
# Scraping college stats for Danny Young (danny-young-1) [5280/5313]
# No college stats found for Danny Young, skipping.
# Scraping college stats for Jahmir Young (jahmir-young-1) [5281/5313]
# Per-game columns for Jahmir Young: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Jahmir Young: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Jahmir Young (jahmir-young-1)
# Scraping college stats for James Young (james-young-1) [5282/5313]
# Per-game columns for James Young: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for James Young: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for James Young (james-young-1)
# Scraping college stats for Joe Young (joe-young-1) [5283/5313]
# No college stats found for Joe Young, skipping.
# Scraping college stats for Korleone Young (korleone-young-1) [5284/5313]
# College page not found for Korleone Young (korleone-young-1)
# No college stats found for Korleone Young, skipping.
# Scraping college stats for Michael Young (michael-young-1) [5285/5313]
# No college stats found for Michael Young, skipping.
# Scraping college stats for Nick Young (nick-young-1) [5286/5313]
# No college stats found for Nick Young, skipping.
# Scraping college stats for Perry Young (perry-young-1) [5287/5313]
# No college stats found for Perry Young, skipping.
# Scraping college stats for Sam Young (sam-young-1) [5288/5313]
# No college stats found for Sam Young, skipping.
# Scraping college stats for Thaddeus Young (thaddeus-young-1) [5289/5313]
# No college stats found for Thaddeus Young, skipping.
# Scraping college stats for Tim Young (tim-young-1) [5290/5313]
# No college stats found for Tim Young, skipping.
# Scraping college stats for Trae Young (trae-young-1) [5291/5313]
# Per-game columns for Trae Young: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Trae Young: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Trae Young (trae-young-1)
# Scraping college stats for Sun Yue (sun-yue-1) [5292/5313]
# College page not found for Sun Yue (sun-yue-1)
# No college stats found for Sun Yue, skipping.
# Scraping college stats for Omer Yurtseven (omer-yurtseven-1) [5293/5313]
# Per-game columns for Omer Yurtseven: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Omer Yurtseven: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Omer Yurtseven (omer-yurtseven-1)
# Scraping college stats for Max Zaslofsky (max-zaslofsky-1) [5294/5313]
# No college stats found for Max Zaslofsky, skipping.
# Scraping college stats for Zeke Zawoluk (zeke-zawoluk-1) [5295/5313]
# College page not found for Zeke Zawoluk (zeke-zawoluk-1)
# No college stats found for Zeke Zawoluk, skipping.
# Scraping college stats for Cody Zeller (cody-zeller-1) [5296/5313]
# Per-game columns for Cody Zeller: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Cody Zeller: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Cody Zeller (cody-zeller-1)
# Scraping college stats for Dave Zeller (dave-zeller-1) [5297/5313]
# No college stats found for Dave Zeller, skipping.
# Scraping college stats for Gary Zeller (gary-zeller-1) [5298/5313]
# No college stats found for Gary Zeller, skipping.
# Scraping college stats for Harry Zeller (harry-zeller-1) [5299/5313]
# College page not found for Harry Zeller (harry-zeller-1)
# No college stats found for Harry Zeller, skipping.
# Scraping college stats for Luke Zeller (luke-zeller-1) [5300/5313]
# No college stats found for Luke Zeller, skipping.
# Scraping college stats for Tyler Zeller (tyler-zeller-1) [5301/5313]
# Per-game columns for Tyler Zeller: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Awards', 'PlayerName', 'CollegeID']
# Advanced columns for Tyler Zeller: ['Season', 'Team', 'Conf', 'Class', 'Pos', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'PProd', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/40', 'OBPM', 'DBPM', 'BPM', 'Awards', 'PlayerName', 'CollegeID']
# Appended college stats for Tyler Zeller (tyler-zeller-1)
# Scraping college stats for Tony Zeno (tony-zeno-1) [5302/5313]
# No college stats found for Tony Zeno, skipping.
# Scraping college stats for Phil Zevenbergen (phil-zevenbergen-1) [5303/5313]
# No college stats found for Phil Zevenbergen, skipping.
# Scraping college stats for Wang Zhizhi (wang-zhizhi-1) [5304/5313]
# College page not found for Wang Zhizhi (wang-zhizhi-1)
# No college stats found for Wang Zhizhi, skipping.
# Scraping college stats for George Zídek (george-zídek-1) [5305/5313]
# College page not found for George Zídek (george-zídek-1)
# No college stats found for George Zídek, skipping.
# Scraping college stats for Derrick Zimmerman (derrick-zimmerman-1) [5306/5313]
# No college stats found for Derrick Zimmerman, skipping.
# Scraping college stats for Stephen Zimmerman (stephen-zimmerman-1) [5307/5313]
# College page not found for Stephen Zimmerman (stephen-zimmerman-1)
# No college stats found for Stephen Zimmerman, skipping.
# Scraping college stats for Paul Zipser (paul-zipser-1) [5308/5313]
# College page not found for Paul Zipser (paul-zipser-1)
# No college stats found for Paul Zipser, skipping.
# Scraping college stats for Ante Žižić (ante-žižić-1) [5309/5313]
# College page not found for Ante Žižić (ante-žižić-1)
# No college stats found for Ante Žižić, skipping.
# Scraping college stats for Jim Zoet (jim-zoet-1) [5310/5313]
# No college stats found for Jim Zoet, skipping.
# Scraping college stats for Bill Zopf (bill-zopf-1) [5311/5313]
# No college stats found for Bill Zopf, skipping.
# Scraping college stats for Ivica Zubac (ivica-zubac-1) [5312/5313]
# College page not found for Ivica Zubac (ivica-zubac-1)
# No college stats found for Ivica Zubac, skipping.
# Scraping college stats for Matt Zunic (matt-zunic-1) [5313/5313]
# College page not found for Matt Zunic (matt-zunic-1)
# No college stats found for Matt Zunic, skipping.
